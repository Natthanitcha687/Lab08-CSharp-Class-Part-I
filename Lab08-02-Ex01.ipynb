# %% [markdown]
# # Lab 8 Exercise 1
# ##  การสร้าง Class

# %% [markdown]
# 1. สร้าง console application project

# %% [markdown]
# 1.1 เรียก terminal (cmd) ขึ้นมา
#
# 1.2 ตรวจสอบให้แน่ใจว่าอยู่ใน folder หรือ directory ที่ต้องการสร้าง project
#
# 1.3 พิมพ์คำสั่งต่อไปนี้
#
# ```
#     dotnet new console --name Lab08_Ex01
# ```
#
# 1.4 ใช้คำสั่ง dir เพื่อตรวจสอบดูว่าโฟลเดอร์ของ project ได้ถูกสร้างขึ้นแล้วหรือยัง

# %% [markdown]
# 2. เปลี่ยน code ในไฟล์ program.cs ให้เป็นดังต่อไปนี้ (ตัวเลขข้างหน้า คือหมายเลขบรรทัด ไว้สำหรับอ้างอิง)
#
# > ```c#
# > 1.  Person p = new Person();
# > 2.  System.Console.WriteLine($"Type of p is {p.GetType()}");
# > 3.
# > 4.  class Person
# > 5.  {
# > 6.
# > 7.  }
# > ```

# %% [markdown]
# 3. Build project โดยการใช้คำสั่ง
#
# ```
# dotnet build  Lab08_Ex01
# ```

# %% [markdown]
# 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Run project โดยการใช้คำสั่ง
#
# ```
# dotnet run --project Lab08_Ex01
# ```

# %% [markdown]
# 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. โค้ดต่อไปนี้สามารถรันได้ใน polyglot notebook หรือไม่

# %%
Person p = new Person();
System.Console.WriteLine($"Type of p is {p.GetType()}");

class Person
{

}
# Out:
# Type of p is Submission#1+Person

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# ได้ Type of p is Submission#1+Person

# %% [markdown]
# ## คำถาม

# %% [markdown]
# 1. Class ในภาษา C# คืออะไร

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# แม่พิมพ์หรือแบบแปลนสำหรับสร้าง Object (วัตถุ) ในโปรแกรม

# %% [markdown]
# 2. Class มีหน้าที่อะไร

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# กำหนดโครงสร้างและพฤติกรรมของ Object ที่จะถูกสร้างขึ้น

# %% [markdown]
# 3. ทำไมเราต้องใช้ Class

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# ช่วยจัดระเบียบโค้ด ลดความซ้ำซ้อน และทำให้โปรแกรมมีความยืดหยุ่นมากขึ้น

# %% [markdown]
# 4. ส่วนประกอบของ Class มีอะไรบ้าง

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# Fields: ตัวแปรที่เก็บข้อมูลของ Object
# Methods: ฟังก์ชันที่กำหนดพฤติกรรมของ Object
# Properties: คุณสมบัติของ Object ที่สามารถเข้าถึงและแก้ไขได้
# Constructors: เมธอดพิเศษที่ใช้สร้าง Object

# %% [markdown]
# 5. Class และ Object แตกต่างกันอย่างไร

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# Class คือแม่พิมพ์ ส่วน Object คือสิ่งที่ถูกสร้างขึ้นตามแม่พิมพ์นั้น

# %% [markdown]
# 6. การตั้งชื่อ Class มีหลักเกณฑ์อย่างไร

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# ใช้คำนาม
# ขึ้นต้นด้วยตัวพิมพ์ใหญ่
# สื่อถึงความหมายของ Class

# %% [markdown]
# 7. คำสั่ง p.GetType() คืออะไร

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# เมธอดที่ใช้ตรวจสอบชนิดของ Object

# %% [markdown]
# 8. ผลที่ได้จากคำสั่ง  p.GetType() คืออะไร มันให้ข้อมูลอะไรแก่เราบ้าง

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# สดงข้อมูลเกี่ยวกับชนิดของ Object

# %% [markdown]
# 9. ในภาษา C# การประกาศ class ไว้ก่อนหรือหลังการสร้าง  object ต่างกันหรือไม่

# %% [markdown]
# *คำตอบ*

# %% [markdown]
# ไม่มีความแตกต่างกันใน C# สามารถประกาศ Class ก่อนหรือหลังการสร้าง Object ก็ได้
